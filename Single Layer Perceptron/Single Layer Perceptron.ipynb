# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron

# %%
df = pd.read_csv("perceptron_dataset.csv")

# %%
df.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -1.640246   1.349568  -2.422994  -1.348925   0.541228   3.753244
# 1   1.719065   0.115966   0.894812   0.678798  -1.833447   1.861899
# 2  -0.507046   0.589878   3.279435   0.852338   0.925272   1.319197
# 3   1.066942  -1.335431   3.662829   1.907967   0.049708   2.499506
# 4  -1.460296   1.262154  -3.750006  -0.897391   0.644849   3.675828
#
#    feature_6  feature_7  feature_8  feature_9  label
# 0  -1.128020   1.736116  -0.042302  -2.290278      0
# 1  -1.007716  -2.436838   0.887480   2.364991      1
# 2  -0.608494   6.034551   0.963456   0.576854      1
# 3   1.288959  -2.205657   0.222749   0.410450      1
# 4  -0.842359  -0.172687  -2.493188  -0.821247      0

# %%
#x = df.iloc[:,:-1]
x_2d = x.iloc[:,:2]#  2d mein plotting hoty hai is lye sirf phle 2 columns lye

# %%
y = df["label"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_2d,y,test_size = 0.2)

# %%
p = Perceptron()

# %%
p.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
y_pred = p.predict(x_test)

# %%
score = p.score(x_test , y_test)*100
print(score)
# Out:
# 50.7

# %%
p.coef_ #gives the values of weights
# Out:
# array([[-2.1950134 , -1.22110019]])

# %%
p.intercept_ #give sthe values of bias
# Out:
# array([0.])

# %%
from mlxtend.plotting import plot_decision_regions
x_2d = x.iloc[:,:2]
plot_decision_regions(x_2d.values,y.values,clf=p)
# Out:
# C:\Program Files\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
