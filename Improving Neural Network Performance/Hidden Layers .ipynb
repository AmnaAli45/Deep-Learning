# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_circles
from mlxtend.plotting import plot_decision_regions

# %%
x,y = make_circles(n_samples = 100 , noise = 0.1 , random_state = 1)

# %%
x.shape
# Out:
# (100, 2)

# %%
df = pd.DataFrame (x,columns = ['Feature1','Feature2'])
df['Label'] = y

# %%
df.head()
# Out:
#    Feature1  Feature2  Label
# 0 -0.636405 -0.368702      1
# 1 -0.244660 -0.736592      1
# 2 -0.465971 -1.066877      0
# 3 -0.709998 -0.408419      1
# 4  0.702322 -0.517301      1

# %%
plt.scatter (df['Feature1'],df['Feature2'],c = y)
plt.xlabel('Feature1')
plt.xlabel('Feature2')
plt.title("Circles")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 ,random_state =42)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128,activation= 'relu' ,input_dim = 2))

model.add(Dense(1,activation= 'sigmoid' ))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_57 (Dense)                     │ (None, 128)                 │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_58 (Dense)                     │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss = 'binary_crossentropy',metrics = ['accuracy'])
history = model.fit(x_train,y_train,validation_split = 0.2,epochs = 3500,verbose = 1)
# Out:
# Epoch 1/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.5312 - loss: 0.6821 - val_accuracy: 0.5000 - val_loss: 0.6849
# Epoch 2/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5469 - loss: 0.6790 - val_accuracy: 0.5000 - val_loss: 0.6846
# Epoch 3/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5156 - loss: 0.6798 - val_accuracy: 0.5000 - val_loss: 0.6838
# Epoch 4/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5469 - loss: 0.6793 - val_accuracy: 0.5000 - val_loss: 0.6841
# Epoch 5/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5625 - loss: 0.6763 - val_accuracy: 0.5000 - val_loss: 0.6840
# Epoch 6/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5625 - loss: 0.6764 - val_accuracy: 0.5000 - val_loss: 0.6841
# Epoch 7/3500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5625 - loss: 0.6752 - val_accuracy: 0.5000 - val_loss: 0.6841
# Epoch 8/3500
# ...

# %%
plt.plot(history.history['loss'] , label = 'test')
plt.plot(history.history['val_loss'] , label = 'test')
plt.show()

# %%
plt.plot(history.history['accuracy'] , label = 'test')
plt.plot(history.history['val_accuracy'] , label = 'test')
plt.show()

# %%
plot_decision_regions(x_test.values,y_test.ravel(),clf = model)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step
# <Axes: >

# %% [markdown]
# # Increasing the number of hidden layers

# %%
model2 = Sequential()
model2.add(Dense(32,activation= 'relu' ,input_dim = 2))
model2.add(Dense(32,activation= 'relu' ))
model2.add(Dense(32,activation= 'relu' ))
model2.add(Dense(32,activation= 'relu' ))
model2.add(Dense(32,activation= 'relu' ))
model2.add(Dense(32,activation= 'relu' ))

model2.add(Dense(1,activation= 'sigmoid' ))
# Out:
# C:\Program Files\Python310\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2.compile(loss = 'binary_crossentropy',metrics = ['accuracy'])
history = model2.fit(x_train,y_train,validation_split = 0.2,epochs = 10,verbose = 1)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.4688 - loss: 0.6954 - val_accuracy: 0.5312 - val_loss: 0.6910
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5078 - loss: 0.6926 - val_accuracy: 0.5312 - val_loss: 0.6896
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4844 - loss: 0.6905 - val_accuracy: 0.5312 - val_loss: 0.6883
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5078 - loss: 0.6892 - val_accuracy: 0.5312 - val_loss: 0.6868
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5156 - loss: 0.6881 - val_accuracy: 0.5625 - val_loss: 0.6860
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5156 - loss: 0.6859 - val_accuracy: 0.5625 - val_loss: 0.6856
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5156 - loss: 0.6858 - val_accuracy: 0.5625 - val_loss: 0.6853
# Epoch 8/10
# ...

# %%
plt.plot(history.history['loss'] , label = 'test')
plt.plot(history.history['val_loss'] , label = 'test')
plt.show()

# %%
plt.plot(history.history['accuracy'] , label = 'test')
plt.plot(history.history['val_accuracy'] , label = 'test')
plt.show()

# %%
plot_decision_regions(x_test.values,y_test.ravel(),clf = model)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# <Axes: >

# %%
_,train = model.evaluate(x_train,y_train,verbose = 0)
_,test = model.evaluate(x_test,y_test,verbose = 0)

# %%
print(train,test)
# Out:
# 0.44999998807907104 0.375
