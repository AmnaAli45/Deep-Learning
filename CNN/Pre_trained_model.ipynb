# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
import numpy as np

# %% [markdown]
# # Load Pre-trained model

# %%
model = ResNet50(weights = 'imagenet') # ye model imagenet dataset prr train hua hai

# %% [markdown]
# # Image 1

# %%
image_path = 'images/bread.jpg' 
img = image.load_img(image_path,target_size = (224,224))

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)

# %%
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 2s 53us/step
# [('n07684084', 'French_loaf', np.float32(0.33347532)), ('n07860988', 'dough', np.float32(0.0961957)), ('n01768244', 'trilobite', np.float32(0.0839334))]

# %% [markdown]
# ### Correctly classified

# %% [markdown]
# # Image 2

# %%
image_path = 'images/tomato.jpg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Predicted:
# [('n12620546', 'hip', np.float32(0.86077845)), ('n07745940', 'strawberry', np.float32(0.088541105)), ('n02948072', 'candle', np.float32(0.007709612))]

# %% [markdown]
# ### wrong Classified

# %% [markdown]
# # Image 3

# %%
image_path = 'images/book.jpg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted:
# [('n03388043', 'fountain', np.float32(0.7736923)), ('n04259630', 'sombrero', np.float32(0.06415863)), ('n03876231', 'paintbrush', np.float32(0.037556257))]

# %% [markdown]
# ### Wrong Classified

# %% [markdown]
# # Image 4

# %%
image_path = 'images/car.jpg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted:
# [('n04285008', 'sports_car', np.float32(0.628527)), ('n04037443', 'racer', np.float32(0.098141566)), ('n04467665', 'trailer_truck', np.float32(0.05732792))]

# %% [markdown]
# ### Correctly Classified

# %% [markdown]
# # Image 5

# %%
image_path = 'images/butterfly.jpg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted:
# [('n02281787', 'lycaenid', np.float32(0.9884813)), ('n02277742', 'ringlet', np.float32(0.0061958707)), ('n02280649', 'cabbage_butterfly', np.float32(0.0037993332))]

# %% [markdown]
# ### Correctly Classified

# %% [markdown]
# # Image 6

# %%
image_path = 'images/airplane.jpeg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Predicted:
# [('n01608432', 'kite', np.float32(0.31485635)), ('n01824575', 'coucal', np.float32(0.20527484)), ('n02051845', 'pelican', np.float32(0.19011323))]

# %% [markdown]
# ### Wrong classified

# %% [markdown]
# # Image 7

# %%
image_path = 'images/lion.jpeg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted:
# [('n02129165', 'lion', np.float32(0.981128)), ('n02389026', 'sorrel', np.float32(0.012094118)), ('n02437312', 'Arabian_camel', np.float32(0.0028446943))]

# %% [markdown]
# ### Correctly classified

# %% [markdown]
# # Image 8

# %%
image_path = 'images/lotus.jpeg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted:
# [('n02190166', 'fly', np.float32(0.08668309)), ('n02206856', 'bee', np.float32(0.05349208)), ('n02219486', 'ant', np.float32(0.03747849))]

# %% [markdown]
# ### Wrong Classified

# %% [markdown]
# # Image 9

# %%
image_path = 'images/deer.jpeg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted:
# [('n02422106', 'hartebeest', np.float32(0.8378558)), ('n02417914', 'ibex', np.float32(0.060760207)), ('n02422699', 'impala', np.float32(0.050722774))]

# %% [markdown]
# ### correctly Classified

# %% [markdown]
# # Image 10

# %%
image_path = 'images/chair.jpeg' 
img = image.load_img(image_path,target_size = (224,224))
plt.imshow(img)

# %%
x = image.img_to_array(img)
x= np.expand_dims(x,axis= 0) # ye reshape kre ga aur 1 add kre ga as a batch size
x = preprocess_input(x)
preds = model.predict(x)
print("Predicted:" )
print(decode_predictions(preds , top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted:
# [('n03201208', 'dining_table', np.float32(0.6005873)), ('n03179701', 'desk', np.float32(0.31560627)), ('n03376595', 'folding_chair', np.float32(0.01920701))]

# %% [markdown]
# ### Correctly Classified
